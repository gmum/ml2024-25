# %% [markdown]
# # Zasady zaliczenia przedmiotu
#
# ## Cel przedmiotu
# - Zaznajomienie z podstawami Machine Learningu (ML) na przykładzie względnie prostych problemów i datasetów
# - Zaznajomienie z podstawami sztucznych sieci neuronowych, z naciskiem na obecnie popularne metody głębokiego uczenia
# - Zapoznanie z używaną terminologią w ML
# - Zwrócenie uwagi na pewne kwestie matematyczne pojawiające się w ML
#
# ## Wymagania wstępne
# - Programowanie w języku Python
# - Podstawy rachunku prawdopodobieństwa
# - Podstawy algebry liniowej
# - Podstawy analizy matematycznej
#
# ## Uwagi
# - Materiał wykładany na tym przedmiocie w dużym stopniu pokrywa się z anglojęzycznymi kursami dostępnymi online
#
# ## Obecność na zajęciach
# - Obecność na wykładzie nie jest obowiązkowa, jednak:
#   * materiał wyłożony na wykładzie obowiązuje na ćwiczeniach
#   * w szczególności dotyczy to znajomości i zrozumienia wzorów matematycznych
#   * w trakcie ćwiczeń NIE będzie tłumaczony materiał z wykładu - wszystkie wątpliwości dotyczące materiału należy zgłaszać na bieżąco w trakcie trwania wykładu
# - Obecność na ćwiczeniach jest obowiązkowa
#   * można mieć co najwyżej dwie nieobecności na ćwiczeniach
#   * nieobecność nie zwalnia z obowiązku oddawania zadań
#   * obowiązkiem uczestnika zajęć jest uzyskanie informacji o przekazanych na zajęciach wiadomościach

# %% [markdown]
# # Zasady oceniania
# ---
#
# ## Ocena z ćwiczeń
#
# Ocena z ćwiczeń będzie opierać się na cotygodniowych zadaniach domowych. Punkty można również zdobyć za realizację projektu we współpracy z GMUMem lub za rozwiązanie bonusowego notebooka.
#
#
# ### Zadania domowe
# 1. Na początku semestru należy założyć prywatne repozytorium na GitHubie przeznaczone na rozwiązane notebooki oraz dać dostęp do repozytorium prowadzącemu ćwiczenia.
# 2. W trakcie zajęć studenci otrzymają do wypełnienia notebook z ćwiczeniami. Notebook z danych zajęć należy uzupełnić do godziny 23:59 w dniu poprzedzająctm kolejne zajęcia oraz wysłać prowadzącemu mejla z listą wykonanych zadań oraz link do prywatnego repozytorium z rozwiązaniami. Mejl powinien mieć następującą formę:
#     * Tytuł: ML_<nr notebooka>_<imię>_<nazwisko>, np. ML_01_Jan_Kowalski,
#     * Treść: lista wykonanych zadań (np. 1, 3, 5), link do prywatnego repozytorium z rozwiązanym notebookiem oraz załączoną kopię tego notebooka, która będzie służyła prowadzącemu do weryfikacji rozwiązań.
# 3. Przyznawanie punktów:
#     * Punkty za rozwiązany notebook będą przyznawane w przeciągu tygodnia od deadline'u na wysłanie rozwiązań. Punkty przyznawane będą na podstawie listy zadeklarowanych zadań.
#     * Prowadzący będzie wyrywkowo weryfikował, czy zadeklarowane zadania zostały rzeczywiście poprawnie rozwiązane.
#     * W przypadku, gdy student zadeklarował zadanie, którego nie rozwiązał, rozwiązał je z rażącymi błędami, lub rozwiązał niesamodzielnie, otrzyma 10 punktów karnych, które zostaną odjęte do oceny końcowej z ćwiczeń (skala 0-100).
#     * Za drugą w semestrze niezgodną z prawdą deklarację otrzyma 20 puntków karnych, a za trzecią - 50 punktów karnych (co oznacza niezdanie przedmiotu).
#     * W przypadku, gdy w zadeklarowanym rozwiązaniu pojawią się drobne błędy lub niedociągniecią, punkty za zadanie zostaną odpowiednio pomniejszone, bez przyznawania punktów karnych.
#     * W przypadku wątpliwości bądź problemów z rozwiązaniem zadania, proszę o konsultację z prowadzącym w terminie podanym w README.md.
# 4. Rozwiązania zadań muszą spełniać następujące kryteria:
#     - kod musi być czytelny i zwięzły (w razie wątpliwości proszę stosować się do standardu PEP 8),
#     - kod musi być przetestowany i poprawnie działać,
#     - jeśli do zadania dodane są asserty/testy, kod musi je przechodzić,
#     - rozwiązanie musi zostać wysłane w terminie,
#     - *komórki oddanego notebooka muszą być wykonane z widocznym rezultatem (prowadzący nie będzie uruchamiał notebooków).*
# 5. Na zajęciach student może być poproszony o przedstawienie fragmentu lub całości zadeklarowanego rozwiązania i wytłumaczenie działania kodu. W przypadku, gdy student nie będzie w stanie wytłumaczyć działania kodu, będzie traktowane to jako przesłanka do tego, że zadanie zostało rozwiązane niesamodzielnie.
# 6. Punkty z każdego niebonusowego notebooka (poza "01_zasady_wstep", za któregeo nie otrzymuje się żadnych punktów) będą skalowane do przedziału 0-10 punktów.
# 7. Suma punktów ze wszystkich notebooków będzie przeskalowana do 80 punktów.
# 8. Za krótkie presentacji w trakcie ćwiczeń można otrzymać 10 punktów.
#
# Osoby dołączające do zajęć w późniejszym terminie muszą liczyć się z faktem, iż nie mogą otrzymać punktów za zaległe zadania.
#
# Rozwiązania notebooków do wglądu dodawane będą do repozytorium po upływie terminów oddania wszystkich grup.
#
# ### Projekt we współpracy z GMUMem
# Do 18.11.2024 można (mejlowo) zadeklarować temat projektu związanego z nauczaniem maszynowym, nad którym student będzie pracował we współpracy z GMUM. Koordynatorem projektu powinien być doktorant lub pracownik naukowy. W szczególności, projekt może być współdzielony z innymi przedmiotami (np. z przedmiotem Projekt Indywidualny), o ile ma on ścisły związek z nauczaniem maszynowym.
#
# - Projekt będzie oceniany na podstawie raportu (PDF, maksymalnie 2 strony), krótkiej prezentacji w trakcie ćwiczeń oraz opinii koordynatora projektu.
# - Termin oddania raportu zostanie ustalony w późniejszym czasie.
# - Za projekt można otrzymać 20 punktów.
#
#
# Z ćwiczeń można otrzymać maksymalnie 100 punktów (80 za niebonusowe notebooki, 10 za presentacji w trakcie ćwiczeń, 10 za aktywność w trakcie ćwiczeń oraz 20 za projekt, uciętę do 100).
# Punkty z ćwiczeń przekładają się na ocenę w następujący sposób:
# * [0-50) pkt: 2
# * [50-64) pkt: 3
# * [64-76) pkt: 3,5
# * [76-86) pkt: 4
# * [86-94) pkt: 4,5
# * [94-100) pkt: 5
#
# ### Zwolnienie z egzaminu
# Osoby z oceną 5.0 z ćwiczeń będą zwolnione z egzaminu i automatycznie otrzymają ocenę 5.0 z całego przedmiotu.
#
# ```
# # Ocena z ćwiczeń
# punktacja_z_cwiczen = min(punktacja_z_notebookow + punktacja_z_projektu, 100)
# ocena_z_cwiczen = skala_quazi_log(punktacja_z_cwiczen)
#
# # Ocena z przedmiotu
# if ocena_z_cwiczen == 5:
#     ocena_z_przedmiotu = 5
# else:
#    punktacja = 0.4 * punktacja_z_egzaminu + 0.6 * punktacja_z_cwiczen
#    ocena_z_przedmiotu = skala_quazi_log(punktacja)
# ```
#
# ## Ocena końcowa
#
# Studenci, którzy otrzymali pozytywną ocenę z ćwiczeń (co najmniej 3.0) mają prawo i obowiązek przystąpić do egzaminu pisemnego. Egzamin końcowy w pierwszym terminie przeprowadzony będzie w formie pisemnej. Ocena końcowa z przedmiotu jest oceną łączną z ćwiczeń i egzaminu. Za egzamin można otrzymać 0-100 pkt.
#
# Punktacja końcowa = 0.4 * punkty z egzaminu + 0.6 * punkty z ćwiczeń
#
# Punkty końcowe przekładają się na ocenę końcową w następujący sposób:
# * [0-50) pkt: 2
# * [50-64) pkt: 3
# * [64-76) pkt: 3,5
# * [76-86) pkt: 4
# * [86-94) pkt: 4,5
# * [94-100) pkt: 5
#
# W wypadku uzyskania w pierwszym terminie oceny niedostatecznej, student ma prawo podejść do egzaminu w DRUGIM TERMINIE.

# %% [markdown]
# ## Samodzielna praca
#
# Celem przedmiotu jest przede wszystkim przygotowanie studentów do dalszej działalności w dziedzinie Machine Learning. W związku z tym zachęcamy studentów do:
# - aktywnego uczestnictwa w zajęciach,
# - korzystania z wyznaczonych przez nas terminów konsultacji,
# - dyskutowania między sobą na temat wykładów i ćwiczeń oraz zadawanych zadań.
#
# Jednakże aby ocena z przedmiotu wystawiona została sprawiedliwie, część pracy musi zostać wykonana samodzielnie przez studenta. Aby uniknąć niepotrzebnych nieporozumień, proszę bardzo dokładnie zapoznać się z poniższymi zasadami.
#
# 1. Dyskusja na temat zadawanych zadań może dotyczyć jedynie ogólnej postaci algorytmu. Prosimy w miarę możliwości zadawać pytania dotyczące zadań na ćwiczeniach.
#
# 2. Niedozwolone jest:
#     - udostępnianie innym studentom rozwiązania zadania w formie szczegółowego (krok po kroku) opisu algorytmu lub kodu,
#     - posługiwanie się notatkami w trakcie trwania egzaminu końcowego, "ściąganie".
#
# Każdy student, który stwierdzi naruszenie powyższych zasad, ma obowiązek poinformować o tym koordynatora przedmiotu.
#
# W zależności od skali przewinienia kary za złamanie powyższych zasad to:
# - bezwarunkowe obniżenie oceny końcowej z przedmiotu,
# - bezwarunkowe NZAL z całego przedmiotu,
# - postępowanie dyscyplinarne.
